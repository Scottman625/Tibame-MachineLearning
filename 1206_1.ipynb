# %% [markdown]
# <a href="https://colab.research.google.com/github/Scottman625/ml1206/blob/main/1206_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
iris = load_iris(as_frame=True)
df = iris["data"]
df["ans"] = iris["target"]
df.to_csv("iris.csv",encoding="utf-8" , index=False)
df

# %%
import numpy as np
x = df.drop(["ans"], axis=1)
y = df["ans"]
x, y = np.array(x), np.array(y)

# %%
from sklearn.model_selection import train_test_split
# 90% input 10% input 90% output 10% ouput
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=2)
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(14, 14))
plot_tree(clf, 
          feature_names=iris["feature_names"],
          class_names=iris["target_names"],
          filled=True)
# Out:
# [Text(312.48, 634.1999999999999, 'petal length (cm) <= 2.45\ngini = 0.666\nsamples = 135\nvalue = [46, 43, 46]\nclass = setosa'),
#  Text(156.24, 380.52, 'gini = 0.0\nsamples = 46\nvalue = [46, 0, 0]\nclass = setosa'),
#  Text(468.72, 380.52, 'petal length (cm) <= 4.95\ngini = 0.499\nsamples = 89\nvalue = [0, 43, 46]\nclass = virginica'),
#  Text(312.48, 126.84000000000003, 'gini = 0.19\nsamples = 47\nvalue = [0, 42, 5]\nclass = versicolor'),
#  Text(624.96, 126.84000000000003, 'gini = 0.046\nsamples = 42\nvalue = [0, 1, 41]\nclass = virginica')]

# %%
from sklearn.metrics import accuracy_score
pre = clf.predict(x_test)
accuracy_score(pre, y_test)
# Out:
# 0.9333333333333333
